# %% [markdown]
# # Multi-Robot Task Allocation – Analysis
#
# ## Metrics
# - Makespan
# - Total distance
# - Idle time
#
# ## Experiment 1: Algorithm Comparison
# (To be filled)
#
# ## Observations
# (To be filled)
