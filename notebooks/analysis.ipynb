# %% [markdown]
# # Multi-Robot Task Allocation – Analysis
#
# ## Metrics
# - Makespan
# - Total distance
# - Idle time
#
# ## Experiment 1: Algorithm Comparison
# (To be filled)
#
# ## Observations
# (To be filled)

# %%
df = pd.read_csv("../results/greedy_results.csv")
df
# Out:
#            algorithm  num_robots  num_tasks  total_distance  makespan  \
# 0  load_aware_greedy           2          3              13         7
# 1  load_aware_greedy           2          2              12         6
# 2  load_aware_greedy           2          3              13         7
# 3  load_aware_greedy           2          4              15         9
# 4  load_aware_greedy           2          5              16         9
#
#    idle_time
# 0          1
# 1          0
# 2          1
# 3          3
# 4          2

# %%
plt.figure()
plt.plot(df["num_tasks"], df["total_distance"], marker="o")
plt.xlabel("Number of Tasks")
plt.ylabel("Total Distance")
plt.title("Total Distance vs Number of Tasks")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(df["num_tasks"], df["makespan"], marker="o")
plt.xlabel("Number of Tasks")
plt.ylabel("Makespan")
plt.title("Makespan vs Number of Tasks")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(df["num_tasks"], df["idle_time"], marker="o")
plt.xlabel("Number of Tasks")
plt.ylabel("Idle Time")
plt.title("Idle Time vs Number of Tasks")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Observations
#
# - Total distance increases with the number of tasks, as expected.
# - Makespan grows gradually, indicating balanced task distribution.
# - Idle time remains low, showing effective utilization of robots.
# - Load-aware greedy allocation improves workload balance compared to naive greedy.
